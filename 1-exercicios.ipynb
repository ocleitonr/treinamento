# %% [markdown]
# ### 1. Ler e exibir um arquivo CSV usando pandas

# %%
df = spark.read.csv("/FileStore/tables/retail.CSV", header=True, sep=';')
df = df.toPandas()

# %% [markdown]
# ### 2. Selecionar colunas específicas de um DataFrame usando pandas

# %%
df[['stock_code','quantity']]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>stock_code</th>
#       <th>quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>85123A</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>71053</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>84406B</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>84029G</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>84029E</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>541904</th>
#       <td>22613</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>541905</th>
#       <td>22899</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>541906</th>
#       <td>23254</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>541907</th>
#       <td>23255</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>541908</th>
#       <td>22138</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# <p>541909 rows × 2 columns</p>
# </div>

# %% [markdown]
# ### 3. Filtrar linhas com base em uma condição usando pandas

# %%
df[df['stock_code'] == '22613']
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>10567</th>
#       <td>537237</td>
#       <td>22613</td>
#       <td>PACK OF 20 SPACEBOY NAPKINS</td>
#       <td>1</td>
#       <td>06/12/2010 09:58</td>
#       <td>1,66</td>
#       <td>None</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>14853</th>
#       <td>537623</td>
#       <td>22613</td>
#       <td>PACK OF 20 SPACEBOY NAPKINS</td>
#       <td>3</td>
#       <td>07/12/2010 14:31</td>
#       <td>0,85</td>
#       <td>15858</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>18129</th>
#       <td>537799</td>
#       <td>22613</td>
#       <td>PACK OF 20 SPACEBOY NAPKINS</td>
#       <td>6</td>
#       <td>08/12/2010 13:07</td>
#       <td>0,85</td>
#       <td>15916</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>29484</th>
#       <td>538799</td>
#       <td>22613</td>
#       <td>PACK OF 20 SPACEBOY NAPKINS</td>
#       <td>1</td>
#       <td>14/12/2010 11:48</td>
#       <td>0,85</td>
#       <td>15039</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>37956</th>
#       <td>539491</td>
#       <td>22613</td>
#       <td>PACK OF 20 SPACEBOY NAPKINS</td>
#       <td>2</td>
#       <td>20/12/2010 10:09</td>
#       <td>0,85</td>
#       <td>14646</td>
#       <td>Netherlands</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>522473</th>
#       <td>580399</td>
#       <td>22613</td>
#       <td>PACK OF 20 SPACEBOY NAPKINS</td>
#       <td>4</td>
#       <td>04/12/2011 11:45</td>
#       <td>0,85</td>
#       <td>13471</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>522958</th>
#       <td>580482</td>
#       <td>22613</td>
#       <td>PACK OF 20 SPACEBOY NAPKINS</td>
#       <td>1</td>
#       <td>04/12/2011 12:44</td>
#       <td>0,85</td>
#       <td>16033</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>532367</th>
#       <td>580983</td>
#       <td>22613</td>
#       <td>PACK OF 20 SPACEBOY NAPKINS</td>
#       <td>1</td>
#       <td>06/12/2011 16:26</td>
#       <td>1,63</td>
#       <td>None</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>532925</th>
#       <td>581001</td>
#       <td>22613</td>
#       <td>PACK OF 20 SPACEBOY NAPKINS</td>
#       <td>12</td>
#       <td>07/12/2011 08:07</td>
#       <td>0,85</td>
#       <td>12583</td>
#       <td>France</td>
#     </tr>
#     <tr>
#       <th>541904</th>
#       <td>581587</td>
#       <td>22613</td>
#       <td>PACK OF 20 SPACEBOY NAPKINS</td>
#       <td>12</td>
#       <td>09/12/2011 12:50</td>
#       <td>0,85</td>
#       <td>12680</td>
#       <td>France</td>
#     </tr>
#   </tbody>
# </table>
# <p>148 rows × 8 columns</p>
# </div>

# %% [markdown]
# ### 4. Agrupar dados com base em uma coluna usando pandas

# %%
df.groupby('invoice_no').agg(n=('description', 'count')).reset_index()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>n</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>536365</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>536366</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>536367</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>536368</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>536369</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>25895</th>
#       <td>C581484</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>25896</th>
#       <td>C581490</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>25897</th>
#       <td>C581499</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>25898</th>
#       <td>C581568</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>25899</th>
#       <td>C581569</td>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>
# <p>25900 rows × 2 columns</p>
# </div>

# %% [markdown]
# ### 5. Usar a função max em alguma coluna do DataFrame

# %%
df['quantity'].max()
# Out:
# Out[22]: '992'
